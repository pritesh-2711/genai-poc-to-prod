# %%
# Basics

"""
1. Important Runnables in langchain - Single function, sequenqial, parallel, branching
2. LCEL - invoke llm calls with string output
3. LCEL - invoke llm calls with structured output
4. LCEL - batch calls, event streaming
5. LCEL - custom runnables, control flow, error handling
6. LCEL - Introduce tools calling
"""
